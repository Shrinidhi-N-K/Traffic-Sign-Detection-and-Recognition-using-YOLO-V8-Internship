# %%
# !pip install ultralytics==8.0.0

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.8/107.7 GB disk)

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/videodata/best.pt conf=0.25 source="/content/drive/MyDrive/videodata/test1.mp4"
# Out:
# 2024-04-30 07:53:59.825485: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 07:53:59.825613: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 07:54:00.053546: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 07:54:02.234272: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU
# Fusing layers...
# Model summary: 168 layers, 11133711 parameters, 0 gradients, 28.5 GFLOPs
# ...

# %%
from IPython.display import Image,display

# %%
Image(filename = f"/content/drive/MyDrive/videodata/Predictions/confusion_matrix.png", height=500)

# %%
Image(filename = f"/content/drive/MyDrive/videodata/Predictions/F1_curve.png", height=500)

# %%
Image(filename = f"/content/drive/MyDrive/videodata/Predictions/results.png", height=500)
